# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt

# IPython magic to create plots within cells and other vars for looks
# %matplotlib inline
pd.options.display.max_rows = 200
matplotlib.style.use('ggplot')

# %%
frbh41 ='https://www.federalreserve.gov/datadownload/Output.aspx?rel=H41&series=e6abcc59dd71a2c3427d7862d2df2715&lastobs=100&from=&to=&filetype=csv&label=include&layout=seriescolumn'

# %%
# CSV generated from URL stored in frbh41 above
# Just re-run the whole notebook to get the latest data

#fed = pd.read_csv('FRB_H41.csv', parse_dates=['Series Description'], skiprows=[1,2,3,4,5])
fed = pd.read_csv(frbh41, parse_dates=['Series Description'], skiprows=[1,2,3,4,5])

fed['ust'] = fed['Assets: Securities Held Outright: U.S. Treasury securities: Wednesday level']
fed = fed.set_index('Series Description')
fed.ust[5:].astype(int).plot(title='FED RESERVE US Treasury Securities')

# %%
print format((fed.ust.max() - fed.ust.min()) / 1000.0, '.2f'), "billion dollars has been dissolved."
# Out:
# 17.52 billion dollars has been dissolved.

# %%
# last 6 months
fed.ust[80:].astype(int).plot(title='FED RESERVE US Treasury Securities (last 6 months)')

# %%
fed.ust[50:]
# Out:
# Series Description
# 2017-02-01    2463426
# 2017-02-08    2463436
# 2017-02-15    2463446
# 2017-02-22    2463456
# 2017-03-01    2463488
# 2017-03-08    2463650
# 2017-03-15    2463812
# 2017-03-22    2463974
# 2017-03-29    2464335
# 2017-04-05    2464454
# 2017-04-12    2464546
# 2017-04-19    2464638
# 2017-04-26    2464730
# 2017-05-03    2464792
# 2017-05-10    2464815
# 2017-05-17    2464638
# 2017-05-24    2464660
# 2017-05-31    2464696
# 2017-06-07    2464783
# 2017-06-14    2464871
# 2017-06-21    2464958
# 2017-06-28    2465046
# 2017-07-05    2465096
# 2017-07-12    2465121
# 2017-07-19    2465145
# 2017-07-26    2465170
# 2017-08-02    2465195
# 2017-08-09    2465221
# 2017-08-16    2465247
# 2017-08-23    2465273
# 2017-08-30    2465300
# 2017-09-06    2465289
# 2017-09-13    2465468
# 2017-09-20    2465448
# 2017-09-27    2465427
# 2017-10-04    2465467
# 2017-10-11    2465554
# 2017-10-18    2465641
# 2017-10-25    2465727
# 2017-11-01    2459827
# 2017-11-08    2459985
# 2017-11-15    2456641
# 2017-11-22    2456822
# 2017-11-29    2456959
# 2017-12-06    2454474
# 2017-12-13    2454256
# 2017-12-20    2454237
# 2017-12-27    2454219
# 2018-01-03    2448208
# 2018-01-10    2448209
# Name: ust, dtype: int64
